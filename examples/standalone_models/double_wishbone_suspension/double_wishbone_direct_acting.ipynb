# %% [markdown]
# # STANDALONE STUDY

# %% [markdown]
# ## **SYSTEM DESCRIPTION**
# -------------------------

# %%
from IPython.display import display, Markdown
display(Markdown(filename='double_wishbone.md'))
# Out:
# # DOUBLE WISHBONE DIRECT ACTING
#
# **STANDALONE TOPOLOGY**
#
# ------------------------------------------------
#
# ### **Summary**
#
# A **double wishbone** mechanism is a type of  independent suspension mechanism used for automotive. It controls the motion of the wheel assembly via two control arms that are connected to the chassis from one end and to the wheel-carrier on the other end, which resembles a **four-bar linkage**, with the chassis being the ground, and the wheel-carrier being the coupler. The wheel-carrier is connected also to the chassis via a tie-rod that constrains the steering of the wheel-assembly as well.
#
# This kinematic chain is augmented with a another simple chain that controls the vertical motion of the wheel-assembly, this simple chain can be a direct-acting coil-over that is connected to either one of the control arms and the chassis, or can be a rocker-push/pull rod mechanism that is connected to the coil-over.
#
# ![Figure 1 - System Layout](double_wishbone.png)
#
# *Figure 1 - Double Wishbone Layout*
#
# --------------------------------------
#
# ### **Topology Layout**
#
# The mechanism consists of 8 Bodies + 1 Ground. Therefore, total system coordinates -including the ground- is $n=n_b\times7 = 9\times7 = 63$, where $n_b$ is the total number of bodies. [^1]
#
# The list of bodies is given below:
#
# - Upper Control Arm **(UCA)**.
# - Lower Control Arm **(LCA)**.
# - Upright.
# - Wheel Hub.
# - Tie-Rod.
# - CoilOver P1.
# - CoilOver P2.
# - Steering Rack.
#
# The system connectivity is given in the table below.
#
# <center>
#
# | Joint Name      | Body i        | Body j      |  Joint Type   | $n_c$ |
# | :-------------- | :------------ | :---------- | :-----------: | ----: |
# | UCA Outer Joint | UCA           | Upright     |   Spherical   |     3 |
# | LCA Outer Joint | LCA           | Upright     |   Spherical   |     3 |
# | Tie-Rod Outer   | Tie-Rod       | Upright     |   Spherical   |     3 |
# | UCA-Chassis     | UCA           | Chassis     |   Revolute    |     5 |
# | LCA-Chassis     | LCA           | Chassis     |   Revolute    |     5 |
# | Hub Bearing     | Wheel-Hub     | Upright     |   Revolute    |     5 |
# | Tie-Rod Inner   | Tie-Rod       | Chassis     |   Universal   |     4 |
# | CoilOver Top    | CoilOver P1   | Chassis     |   Universal   |     4 |
# | CoilOver Bottom | CoilOver P2   | UCA         |   Universal   |     4 |
# | CoilOver Cyl    | CoilOver P1   | CoilOver P2 |  Cylindrical  |     4 |
# | Rack-Chassis    | Steering Rack | Chassis     | Translational |     5 |
# | **Total**       |               |             |               |    45 |
#
# </center>
#
# </br>
#
# Hence, the total number of constraints equations is:
# $$ n_{c} = n_{c_j} + n_{c_p} + n_{c_g} = 45 + (9\times 1) + 6 = 60 $$
#
# where:
# * $n_{c_j}$ is the joints constraints.
# * $n_{c_p}$ is the euler-parameters normalization constraints.
# * $n_{c_g}$ is the ground constraints.
#
# Therefore, the resulting **DOF** is:
# $$ n - n_c = 63 - 60 = 3 $$
#
# which can be interpreted in a convenient way that one DOF is the rotational motion of the wheel, one is the vertical motion and one for the rack travel.
#
# ------------------------------------------------------
# <br/>
#
# [^1]: The tool uses [euler-parameters](https://en.wikibooks.org/wiki/Multibody_Mechanics/Euler_Parameters) -which is a 4D unit quaternion- to represents bodies orientation in space. This makes the generalized coordinates used to fully define a body in space to be **7,** instead of **6**, it also adds an algebraic equation to the constraints that ensures the unity/normalization of the body quaternion. This is an important remark as the calculations of the degrees-of-freedom depends on it.

# %% [markdown]
# -------------------
# -------------------

# %% [markdown]
# ## Environment Setup
# --------------------

# %% [markdown]
# ### Colab Session
# *Run if in a Colab Session Only!*

# %% [markdown]
# #### Setting-up Colab Virtual Machine
# This will install the needed modules into the Virtual Machine dedicated for the running notebook session.

# %%
# !pip install uraeus.smbd

# %% [markdown]
# Creating a new directory, `/uraeus_smbd`, where we can store the model files and results.

# %%
import os

os.mkdir('uraeus_smbd')
os.chdir('uraeus_smbd')

# %% [markdown]
# #### Rendering SymPy in Colab
# Rendering SymPy equations in Colab requires the MathJax javascript library to be available within each cell output. The following defines an execution hook that loads it automatically each time you execute a cell.

# %%
from IPython.display import Math, HTML

def load_mathjax_in_cell_output():
  display(HTML("<script src='https://www.gstatic.com/external_hosted/"
               "mathjax/latest/MathJax.js?config=default'></script>"))
get_ipython().events.register('pre_run_cell', load_mathjax_in_cell_output)

# %% [markdown]
# ---------------------------------------------------------------

# %% [markdown]
# ### Local Session
# *Run if on your Local Machine!*</br>

# %% [markdown]
# Creating Project Directories

# %%
from uraeus.smbd.systems import standalone_project

# %%
project = standalone_project()
project.create()

# %% [markdown]
# ---------------------------------------------------------------
# ---------------------------------------------------------------

# %% [markdown]
# ## SYSTEM MODELING

# %% [markdown]
# ## **SYMBOLIC TOPOLOGY**
# ------------------------

# %% [markdown]
# In this section, we create the symbolic topology that captures the topological layout that we just discussed.</br>
# Defining the topology is very simple. We start by creating an instance of the ```standalone_topology``` class that represents our symbolic model. Then we start adding the components we discussed earlier, starting by the bodies, then the joints, actuators and forces, and thats it.</br>
# These components will be represented symbolically, and therefore there is no need for any numerical inputs at this step.
#
# The system is stored in a form of a network graph that stores all the data needed for the assemblage of the system equations later. But even before the assemblage process, we can gain helpful insights about our system as well be shown.

# %%
from uraeus.smbd.systems import standalone_topology, configuration

# %%
project_name = 'dwb_direct_acting'

# %%
sym_model = standalone_topology(project_name)

# %% [markdown]
# ### Adding Bodies

# %%
# Adding Bodies
# =============
sym_model.add_body('uca', mirror=True)
sym_model.add_body('lca', mirror=True)
sym_model.add_body('upright', mirror=True)
sym_model.add_body('tie_rod', mirror=True)
sym_model.add_body('hub', mirror=True)

sym_model.add_body('upper_strut', mirror=True)
sym_model.add_body('lower_strut' ,mirror=True)

sym_model.add_body('steer_rack')

# %% [markdown]
# ### Adding Joints

# %%
# Adding Joints
# =============

# Upper Control Arm Joints
sym_model.add_joint.spherical('uca_upright', 'rbr_uca', 'rbr_upright', mirror=True)

# Lower Control Arm Joints
sym_model.add_joint.spherical('lca_upright', 'rbr_lca', 'rbr_upright', mirror=True)

# Tie-Rod Joints
sym_model.add_joint.spherical('tie_upright', 'rbr_tie_rod', 'rbr_upright', mirror=True)
sym_model.add_joint.universal('tie_steering', 'rbr_tie_rod', 'rbs_steer_rack', mirror=True)

# Hub Bearing Joint
sym_model.add_joint.revolute('hub_bearing', 'rbr_upright', 'rbr_hub', mirror=True)

# Strut/Coilover Joints
sym_model.add_joint.universal('strut_chassis', 'rbr_upper_strut', 'ground', mirror=True)
sym_model.add_joint.universal('strut_uca', 'rbr_lower_strut', 'rbr_uca', mirror=True)
sym_model.add_joint.cylinderical('strut', 'rbr_upper_strut', 'rbr_lower_strut', mirror=True)

# Steering Rack Joint
sym_model.add_joint.translational('rack', 'rbs_steer_rack', 'ground')

# %% [markdown]
# ### Adding Actuators

# %%
# Adding Actuators
# ================

# Wheel Spin Lock
sym_model.add_actuator.rotational_actuator('wheel_lock', 'jcr_hub_bearing', mirror=True)

# Wheel Vertical Travel
sym_model.add_actuator.absolute_locator('wheel_travel', 'rbr_upright', 'ground', 'z', mirror=True)

# Steering-Rack Travel
sym_model.add_actuator.translational_actuator('rack_travel', 'jcs_rack')

# %% [markdown]
# ### Adding Forces

# %%
# Adding Forces
# =============
sym_model.add_force.internal_force('strut', 'rbr_upper_strut', 'rbr_lower_strut', mirror=True)

# %% [markdown]
# ### **SYMBOLIC CHARACTERISTICS**

# %% [markdown]
# #### Topology Graph
# Visualizing the connectivity of the system as a network graph, where the nodes represent the bodies, and the edges represent the joints, forces and/or actuators between the bodies.

# %%
sym_model.topology.draw_constraints_topology()

# %% [markdown]
# Checking the system's number of generalized coordinates $n$ and number of constraints $n_c$.

# %%
sym_model.topology.n, sym_model.topology.nc
# Out:
# (112, 92)

# %% [markdown]
# ### VARIANT 1

# %%
sym_model.topology.create_subvariant('kinematic')
# Out:
# Current Active Graph : kinematic

# %%
# Adding Joints
# =============

# Upper Control Arm Joints
sym_model.add_joint.revolute('uca_chassis', 'rbr_uca', 'ground', mirror=True)

# Lower Control Arm Joints
sym_model.add_joint.revolute('lca_chassis', 'rbr_lca', 'ground', mirror=True)

# %%
sym_model.topology.draw_constraints_topology()

# %% [markdown]
# Checking the system's number of generalized coordinates $n$ and number of constraints $n_c$.

# %%
sym_model.topology.n, sym_model.topology.nc
# Out:
# (112, 112)

# %% [markdown]
# ### VARIANT 2

# %%
sym_model.topology.create_subvariant('compliant')
# Out:
# Current Active Graph : compliant

# %%
# Adding Bushes
# =============

# Upper Control Arm Bushes
sym_model.add_force.bushing('ucaf_bush', 'rbr_uca', 'ground', mirror=True)
sym_model.add_force.bushing('ucar_bush', 'rbr_uca', 'ground', mirror=True)

# Lower Control Arm Bushes
sym_model.add_force.bushing('lcaf_bush', 'rbr_lca', 'ground', mirror=True)
sym_model.add_force.bushing('lcar_bush', 'rbr_lca', 'ground', mirror=True)

# %%
sym_model.topology.draw_constraints_topology()

# %% [markdown]
# Checking the system's number of generalized coordinates $n$ and number of constraints $n_c$.

# %%
sym_model.topology.n, sym_model.topology.nc
# Out:
# (112, 92)

# %%
import networkx as nx

# %%
g = nx.compose_all(sym_model.topology.variants.values())

# %%
#list(g.edges(data='name'))

# %% [markdown]
# ### **ASSEMBLING**

# %% [markdown]
# This is the last step of the symbolic model building process, where the system starts the assemblage process of the governing equations, which will be used then in the code generation for the numerical simulation, and also can be used for further symbolic manipulations.</br>
#
# *Note: The equations' notations will be discussed in a separate documentation file.*

# %%
sym_model.save('symenv')

# %%
sym_model.assemble()
# Out:
# Current Active Graph : root
# Current Active Graph : base
# Current Active Graph : kinematic
# Current Active Graph : compliant

# %%
list(sym_model.topology.variants['root'].nodes(data=True))
# Out:
# [('ground',
#   {'n': 7,
#    'nc': 7,
#    'nve': 2,
#    'class': uraeus.smbd.symbolic.components.bodies.ground,
#    'mirr': 'ground',
#    'align': 's',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.ground at 0x7fa6e92f4588>,
#    'arguments_symbols': [],
#    'runtime_symbols': [{R_{ground}},
#     {P_{ground}},
#     {\dot{R}_{ground}},
#     {\dot{P}_{ground}},
#     {\ddot{R}_{ground}},
#     {\ddot{P}_{ground}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [Eq({R_{ground}}, Matrix([
#     [0],
#     [0],
#     [0]])), Eq({P_{ground}}, Matrix([
#     [1],
#     [0],
#     [0],
#     [0]])), Eq({Pg_{ground}}, Matrix([
#     [1],
#     [0],
#     [0],
#     [0]])), Eq(m_ground, 1.0), Eq({\bar{J}_{ground}}, Matrix([
#     [1, 0, 0],
#     [0, 1, 0],
#     [0, 0, 1]]))],
#    'constants_symbols': [{R_{ground}},
#     {P_{ground}},
#     {Pg_{ground}},
#     m_ground,
#     {\bar{J}_{ground}}]}),
#  ('rbr_uca',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbl_uca',
#    'align': 'r',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e9273f98>,
#    'arguments_symbols': [{R_{rbr_uca}},
#     {P_{rbr_uca}},
#     {\dot{R}_{rbr_uca}},
#     {\dot{P}_{rbr_uca}},
#     {\ddot{R}_{rbr_uca}},
#     {\ddot{P}_{rbr_uca}},
#     m_rbr_uca,
#     {\bar{J}_{rbr_uca}}],
#    'runtime_symbols': [{R_{rbr_uca}},
#     {P_{rbr_uca}},
#     {\dot{R}_{rbr_uca}},
#     {\dot{P}_{rbr_uca}},
#     {\ddot{R}_{rbr_uca}},
#     {\ddot{P}_{rbr_uca}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbl_uca',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbr_uca',
#    'align': 'l',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa71da2fe48>,
#    'arguments_symbols': [{R_{rbl_uca}},
#     {P_{rbl_uca}},
#     {\dot{R}_{rbl_uca}},
#     {\dot{P}_{rbl_uca}},
#     {\ddot{R}_{rbl_uca}},
#     {\ddot{P}_{rbl_uca}},
#     m_rbl_uca,
#     {\bar{J}_{rbl_uca}}],
#    'runtime_symbols': [{R_{rbl_uca}},
#     {P_{rbl_uca}},
#     {\dot{R}_{rbl_uca}},
#     {\dot{P}_{rbl_uca}},
#     {\ddot{R}_{rbl_uca}},
#     {\ddot{P}_{rbl_uca}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbr_lca',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbl_lca',
#    'align': 'r',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e9285a20>,
#    'arguments_symbols': [{R_{rbr_lca}},
#     {P_{rbr_lca}},
#     {\dot{R}_{rbr_lca}},
#     {\dot{P}_{rbr_lca}},
#     {\ddot{R}_{rbr_lca}},
#     {\ddot{P}_{rbr_lca}},
#     m_rbr_lca,
#     {\bar{J}_{rbr_lca}}],
#    'runtime_symbols': [{R_{rbr_lca}},
#     {P_{rbr_lca}},
#     {\dot{R}_{rbr_lca}},
#     {\dot{P}_{rbr_lca}},
#     {\ddot{R}_{rbr_lca}},
#     {\ddot{P}_{rbr_lca}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbl_lca',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbr_lca',
#    'align': 'l',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e9294b70>,
#    'arguments_symbols': [{R_{rbl_lca}},
#     {P_{rbl_lca}},
#     {\dot{R}_{rbl_lca}},
#     {\dot{P}_{rbl_lca}},
#     {\ddot{R}_{rbl_lca}},
#     {\ddot{P}_{rbl_lca}},
#     m_rbl_lca,
#     {\bar{J}_{rbl_lca}}],
#    'runtime_symbols': [{R_{rbl_lca}},
#     {P_{rbl_lca}},
#     {\dot{R}_{rbl_lca}},
#     {\dot{P}_{rbl_lca}},
#     {\ddot{R}_{rbl_lca}},
#     {\ddot{P}_{rbl_lca}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbr_upright',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbl_upright',
#    'align': 'r',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e9294400>,
#    'arguments_symbols': [{R_{rbr_upright}},
#     {P_{rbr_upright}},
#     {\dot{R}_{rbr_upright}},
#     {\dot{P}_{rbr_upright}},
#     {\ddot{R}_{rbr_upright}},
#     {\ddot{P}_{rbr_upright}},
#     m_rbr_upright,
#     {\bar{J}_{rbr_upright}}],
#    'runtime_symbols': [{R_{rbr_upright}},
#     {P_{rbr_upright}},
#     {\dot{R}_{rbr_upright}},
#     {\dot{P}_{rbr_upright}},
#     {\ddot{R}_{rbr_upright}},
#     {\ddot{P}_{rbr_upright}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbl_upright',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbr_upright',
#    'align': 'l',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e9294128>,
#    'arguments_symbols': [{R_{rbl_upright}},
#     {P_{rbl_upright}},
#     {\dot{R}_{rbl_upright}},
#     {\dot{P}_{rbl_upright}},
#     {\ddot{R}_{rbl_upright}},
#     {\ddot{P}_{rbl_upright}},
#     m_rbl_upright,
#     {\bar{J}_{rbl_upright}}],
#    'runtime_symbols': [{R_{rbl_upright}},
#     {P_{rbl_upright}},
#     {\dot{R}_{rbl_upright}},
#     {\dot{P}_{rbl_upright}},
#     {\ddot{R}_{rbl_upright}},
#     {\ddot{P}_{rbl_upright}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbr_tie_rod',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbl_tie_rod',
#    'align': 'r',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e9294da0>,
#    'arguments_symbols': [{R_{rbr_tie_rod}},
#     {P_{rbr_tie_rod}},
#     {\dot{R}_{rbr_tie_rod}},
#     {\dot{P}_{rbr_tie_rod}},
#     {\ddot{R}_{rbr_tie_rod}},
#     {\ddot{P}_{rbr_tie_rod}},
#     m_rbr_tie_rod,
#     {\bar{J}_{rbr_tie_rod}}],
#    'runtime_symbols': [{R_{rbr_tie_rod}},
#     {P_{rbr_tie_rod}},
#     {\dot{R}_{rbr_tie_rod}},
#     {\dot{P}_{rbr_tie_rod}},
#     {\ddot{R}_{rbr_tie_rod}},
#     {\ddot{P}_{rbr_tie_rod}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbl_tie_rod',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbr_tie_rod',
#    'align': 'l',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa71ef56cf8>,
#    'arguments_symbols': [{R_{rbl_tie_rod}},
#     {P_{rbl_tie_rod}},
#     {\dot{R}_{rbl_tie_rod}},
#     {\dot{P}_{rbl_tie_rod}},
#     {\ddot{R}_{rbl_tie_rod}},
#     {\ddot{P}_{rbl_tie_rod}},
#     m_rbl_tie_rod,
#     {\bar{J}_{rbl_tie_rod}}],
#    'runtime_symbols': [{R_{rbl_tie_rod}},
#     {P_{rbl_tie_rod}},
#     {\dot{R}_{rbl_tie_rod}},
#     {\dot{P}_{rbl_tie_rod}},
#     {\ddot{R}_{rbl_tie_rod}},
#     {\ddot{P}_{rbl_tie_rod}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbr_hub',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbl_hub',
#    'align': 'r',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e936db00>,
#    'arguments_symbols': [{R_{rbr_hub}},
#     {P_{rbr_hub}},
#     {\dot{R}_{rbr_hub}},
#     {\dot{P}_{rbr_hub}},
#     {\ddot{R}_{rbr_hub}},
#     {\ddot{P}_{rbr_hub}},
#     m_rbr_hub,
#     {\bar{J}_{rbr_hub}}],
#    'runtime_symbols': [{R_{rbr_hub}},
#     {P_{rbr_hub}},
#     {\dot{R}_{rbr_hub}},
#     {\dot{P}_{rbr_hub}},
#     {\ddot{R}_{rbr_hub}},
#     {\ddot{P}_{rbr_hub}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbl_hub',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbr_hub',
#    'align': 'l',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e9314240>,
#    'arguments_symbols': [{R_{rbl_hub}},
#     {P_{rbl_hub}},
#     {\dot{R}_{rbl_hub}},
#     {\dot{P}_{rbl_hub}},
#     {\ddot{R}_{rbl_hub}},
#     {\ddot{P}_{rbl_hub}},
#     m_rbl_hub,
#     {\bar{J}_{rbl_hub}}],
#    'runtime_symbols': [{R_{rbl_hub}},
#     {P_{rbl_hub}},
#     {\dot{R}_{rbl_hub}},
#     {\dot{P}_{rbl_hub}},
#     {\ddot{R}_{rbl_hub}},
#     {\ddot{P}_{rbl_hub}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbr_upper_strut',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbl_upper_strut',
#    'align': 'r',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e938d3c8>,
#    'arguments_symbols': [{R_{rbr_upper_strut}},
#     {P_{rbr_upper_strut}},
#     {\dot{R}_{rbr_upper_strut}},
#     {\dot{P}_{rbr_upper_strut}},
#     {\ddot{R}_{rbr_upper_strut}},
#     {\ddot{P}_{rbr_upper_strut}},
#     m_rbr_upper_strut,
#     {\bar{J}_{rbr_upper_strut}}],
#    'runtime_symbols': [{R_{rbr_upper_strut}},
#     {P_{rbr_upper_strut}},
#     {\dot{R}_{rbr_upper_strut}},
#     {\dot{P}_{rbr_upper_strut}},
#     {\ddot{R}_{rbr_upper_strut}},
#     {\ddot{P}_{rbr_upper_strut}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbl_upper_strut',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbr_upper_strut',
#    'align': 'l',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e9274160>,
#    'arguments_symbols': [{R_{rbl_upper_strut}},
#     {P_{rbl_upper_strut}},
#     {\dot{R}_{rbl_upper_strut}},
#     {\dot{P}_{rbl_upper_strut}},
#     {\ddot{R}_{rbl_upper_strut}},
#     {\ddot{P}_{rbl_upper_strut}},
#     m_rbl_upper_strut,
#     {\bar{J}_{rbl_upper_strut}}],
#    'runtime_symbols': [{R_{rbl_upper_strut}},
#     {P_{rbl_upper_strut}},
#     {\dot{R}_{rbl_upper_strut}},
#     {\dot{P}_{rbl_upper_strut}},
#     {\ddot{R}_{rbl_upper_strut}},
#     {\ddot{P}_{rbl_upper_strut}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbr_lower_strut',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbl_lower_strut',
#    'align': 'r',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e938dcf8>,
#    'arguments_symbols': [{R_{rbr_lower_strut}},
#     {P_{rbr_lower_strut}},
#     {\dot{R}_{rbr_lower_strut}},
#     {\dot{P}_{rbr_lower_strut}},
#     {\ddot{R}_{rbr_lower_strut}},
#     {\ddot{P}_{rbr_lower_strut}},
#     m_rbr_lower_strut,
#     {\bar{J}_{rbr_lower_strut}}],
#    'runtime_symbols': [{R_{rbr_lower_strut}},
#     {P_{rbr_lower_strut}},
#     {\dot{R}_{rbr_lower_strut}},
#     {\dot{P}_{rbr_lower_strut}},
#     {\ddot{R}_{rbr_lower_strut}},
#     {\ddot{P}_{rbr_lower_strut}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbl_lower_strut',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbr_lower_strut',
#    'align': 'l',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e938db38>,
#    'arguments_symbols': [{R_{rbl_lower_strut}},
#     {P_{rbl_lower_strut}},
#     {\dot{R}_{rbl_lower_strut}},
#     {\dot{P}_{rbl_lower_strut}},
#     {\ddot{R}_{rbl_lower_strut}},
#     {\ddot{P}_{rbl_lower_strut}},
#     m_rbl_lower_strut,
#     {\bar{J}_{rbl_lower_strut}}],
#    'runtime_symbols': [{R_{rbl_lower_strut}},
#     {P_{rbl_lower_strut}},
#     {\dot{R}_{rbl_lower_strut}},
#     {\dot{P}_{rbl_lower_strut}},
#     {\ddot{R}_{rbl_lower_strut}},
#     {\ddot{P}_{rbl_lower_strut}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []}),
#  ('rbs_steer_rack',
#   {'n': 7,
#    'nc': 1,
#    'nve': 1,
#    'class': uraeus.smbd.symbolic.components.bodies.body,
#    'mirr': 'rbs_steer_rack',
#    'align': 's',
#    'virtual': False,
#    'obj': <uraeus.smbd.symbolic.components.bodies.body at 0x7fa6e930b3c8>,
#    'arguments_symbols': [{R_{rbs_steer_rack}},
#     {P_{rbs_steer_rack}},
#     {\dot{R}_{rbs_steer_rack}},
#     {\dot{P}_{rbs_steer_rack}},
#     {\ddot{R}_{rbs_steer_rack}},
#     {\ddot{P}_{rbs_steer_rack}},
#     m_rbs_steer_rack,
#     {\bar{J}_{rbs_steer_rack}}],
#    'runtime_symbols': [{R_{rbs_steer_rack}},
#     {P_{rbs_steer_rack}},
#     {\dot{R}_{rbs_steer_rack}},
#     {\dot{P}_{rbs_steer_rack}},
#     {\ddot{R}_{rbs_steer_rack}},
#     {\ddot{P}_{rbs_steer_rack}}],
#    'constants_symbolic_expr': [],
#    'constants_numeric_expr': [],
#    'constants_symbols': []})]

# %%
{tuple(item[:-1]) : item[-1] for item in sym_model.topology.variants['kinematic'].edges(data=True, keys=True)}
# Out:
# {('rbr_uca', 'ground', 'fas_rbr_uca_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbr_uca_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_uca_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e930b2b0>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbr_uca}_{gravity}}, Matrix([
#    [                0],
#    [                0],
#    [-9810.0*m_rbr_uca]]))],
#   'constants_symbols': [{{F}^{rbr_uca}_{gravity}}]},
#  ('rbr_uca', 'ground', 'fas_rbr_uca_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbr_uca_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_uca_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e930bdd8>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbr_uca', 'ground', 'jcr_uca_chassis'): {'n': 0,
#   'nc': 5,
#   'nve': 3,
#   'class': uraeus.smbd.symbolic.components.joints.revolute,
#   'mirr': 'jcl_uca_chassis',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_uca_chassis',
#   'obj': <uraeus.smbd.symbolic.components.joints.revolute at 0x7fa6e92baeb8>,
#   'arguments_symbols': [ax1_jcr_uca_chassis, pt1_jcr_uca_chassis],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_uca}_{jcr_uca_chassis}}, A({P_{rbr_uca}}).T*Triad(ax1_jcr_uca_chassis)),
#    Eq({\bar{M}^{ground}_{jcr_uca_chassis}}, A({P_{ground}}).T*Triad(ax1_jcr_uca_chassis)),
#    Eq({\bar{u}^{rbr_uca}_{jcr_uca_chassis}}, -A({P_{rbr_uca}}).T*{R_{rbr_uca}} + A({P_{rbr_uca}}).T*pt1_jcr_uca_chassis),
#    Eq({\bar{u}^{ground}_{jcr_uca_chassis}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt1_jcr_uca_chassis)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_uca}_{jcr_uca_chassis}},
#    {\bar{M}^{ground}_{jcr_uca_chassis}},
#    {\bar{u}^{rbr_uca}_{jcr_uca_chassis}},
#    {\bar{u}^{ground}_{jcr_uca_chassis}}]},
#  ('rbr_uca', 'rbr_upright', 'jcr_uca_upright'): {'n': 0,
#   'nc': 3,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.spherical,
#   'mirr': 'jcl_uca_upright',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_uca_upright',
#   'obj': <uraeus.smbd.symbolic.components.joints.spherical at 0x7fa6e6bbed30>,
#   'arguments_symbols': [ax1_jcr_uca_upright, pt1_jcr_uca_upright],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_uca}_{jcr_uca_upright}}, A({P_{rbr_uca}}).T*Triad(ax1_jcr_uca_upright)),
#    Eq({\bar{M}^{rbr_upright}_{jcr_uca_upright}}, A({P_{rbr_upright}}).T*Triad(ax1_jcr_uca_upright)),
#    Eq({\bar{u}^{rbr_uca}_{jcr_uca_upright}}, -A({P_{rbr_uca}}).T*{R_{rbr_uca}} + A({P_{rbr_uca}}).T*pt1_jcr_uca_upright),
#    Eq({\bar{u}^{rbr_upright}_{jcr_uca_upright}}, -A({P_{rbr_upright}}).T*{R_{rbr_upright}} + A({P_{rbr_upright}}).T*pt1_jcr_uca_upright)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_uca}_{jcr_uca_upright}},
#    {\bar{M}^{rbr_upright}_{jcr_uca_upright}},
#    {\bar{u}^{rbr_uca}_{jcr_uca_upright}},
#    {\bar{u}^{rbr_upright}_{jcr_uca_upright}}]},
#  ('rbl_uca', 'ground', 'fas_rbl_uca_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbl_uca_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_uca_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6bd3908>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbl_uca}_{gravity}}, Matrix([
#    [                0],
#    [                0],
#    [-9810.0*m_rbl_uca]]))],
#   'constants_symbols': [{{F}^{rbl_uca}_{gravity}}]},
#  ('rbl_uca', 'ground', 'fas_rbl_uca_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbl_uca_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_uca_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6be3d30>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbl_uca', 'ground', 'jcl_uca_chassis'): {'n': 0,
#   'nc': 5,
#   'nve': 3,
#   'class': uraeus.smbd.symbolic.components.joints.revolute,
#   'mirr': 'jcr_uca_chassis',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_uca_chassis',
#   'obj': <uraeus.smbd.symbolic.components.joints.revolute at 0x7fa6e6be3da0>,
#   'arguments_symbols': [ax1_jcl_uca_chassis, pt1_jcl_uca_chassis],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_uca}_{jcl_uca_chassis}}, A({P_{rbl_uca}}).T*Triad(ax1_jcl_uca_chassis)),
#    Eq({\bar{M}^{ground}_{jcl_uca_chassis}}, A({P_{ground}}).T*Triad(ax1_jcl_uca_chassis)),
#    Eq({\bar{u}^{rbl_uca}_{jcl_uca_chassis}}, -A({P_{rbl_uca}}).T*{R_{rbl_uca}} + A({P_{rbl_uca}}).T*pt1_jcl_uca_chassis),
#    Eq({\bar{u}^{ground}_{jcl_uca_chassis}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt1_jcl_uca_chassis)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_uca}_{jcl_uca_chassis}},
#    {\bar{M}^{ground}_{jcl_uca_chassis}},
#    {\bar{u}^{rbl_uca}_{jcl_uca_chassis}},
#    {\bar{u}^{ground}_{jcl_uca_chassis}}]},
#  ('rbl_uca', 'rbl_upright', 'jcl_uca_upright'): {'n': 0,
#   'nc': 3,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.spherical,
#   'mirr': 'jcr_uca_upright',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_uca_upright',
#   'obj': <uraeus.smbd.symbolic.components.joints.spherical at 0x7fa6e6ba2320>,
#   'arguments_symbols': [ax1_jcl_uca_upright, pt1_jcl_uca_upright],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_uca}_{jcl_uca_upright}}, A({P_{rbl_uca}}).T*Triad(ax1_jcl_uca_upright)),
#    Eq({\bar{M}^{rbl_upright}_{jcl_uca_upright}}, A({P_{rbl_upright}}).T*Triad(ax1_jcl_uca_upright)),
#    Eq({\bar{u}^{rbl_uca}_{jcl_uca_upright}}, -A({P_{rbl_uca}}).T*{R_{rbl_uca}} + A({P_{rbl_uca}}).T*pt1_jcl_uca_upright),
#    Eq({\bar{u}^{rbl_upright}_{jcl_uca_upright}}, -A({P_{rbl_upright}}).T*{R_{rbl_upright}} + A({P_{rbl_upright}}).T*pt1_jcl_uca_upright)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_uca}_{jcl_uca_upright}},
#    {\bar{M}^{rbl_upright}_{jcl_uca_upright}},
#    {\bar{u}^{rbl_uca}_{jcl_uca_upright}},
#    {\bar{u}^{rbl_upright}_{jcl_uca_upright}}]},
#  ('rbr_lca', 'ground', 'fas_rbr_lca_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbr_lca_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_lca_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6baefd0>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbr_lca}_{gravity}}, Matrix([
#    [                0],
#    [                0],
#    [-9810.0*m_rbr_lca]]))],
#   'constants_symbols': [{{F}^{rbr_lca}_{gravity}}]},
#  ('rbr_lca', 'ground', 'fas_rbr_lca_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbr_lca_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_lca_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6b49ba8>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbr_lca', 'ground', 'jcr_lca_chassis'): {'n': 0,
#   'nc': 5,
#   'nve': 3,
#   'class': uraeus.smbd.symbolic.components.joints.revolute,
#   'mirr': 'jcl_lca_chassis',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_lca_chassis',
#   'obj': <uraeus.smbd.symbolic.components.joints.revolute at 0x7fa6e6b49da0>,
#   'arguments_symbols': [ax1_jcr_lca_chassis, pt1_jcr_lca_chassis],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_lca}_{jcr_lca_chassis}}, A({P_{rbr_lca}}).T*Triad(ax1_jcr_lca_chassis)),
#    Eq({\bar{M}^{ground}_{jcr_lca_chassis}}, A({P_{ground}}).T*Triad(ax1_jcr_lca_chassis)),
#    Eq({\bar{u}^{rbr_lca}_{jcr_lca_chassis}}, -A({P_{rbr_lca}}).T*{R_{rbr_lca}} + A({P_{rbr_lca}}).T*pt1_jcr_lca_chassis),
#    Eq({\bar{u}^{ground}_{jcr_lca_chassis}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt1_jcr_lca_chassis)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_lca}_{jcr_lca_chassis}},
#    {\bar{M}^{ground}_{jcr_lca_chassis}},
#    {\bar{u}^{rbr_lca}_{jcr_lca_chassis}},
#    {\bar{u}^{ground}_{jcr_lca_chassis}}]},
#  ('rbr_lca', 'rbr_upright', 'jcr_lca_upright'): {'n': 0,
#   'nc': 3,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.spherical,
#   'mirr': 'jcl_lca_upright',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_lca_upright',
#   'obj': <uraeus.smbd.symbolic.components.joints.spherical at 0x7fa6e6afee80>,
#   'arguments_symbols': [ax1_jcr_lca_upright, pt1_jcr_lca_upright],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_lca}_{jcr_lca_upright}}, A({P_{rbr_lca}}).T*Triad(ax1_jcr_lca_upright)),
#    Eq({\bar{M}^{rbr_upright}_{jcr_lca_upright}}, A({P_{rbr_upright}}).T*Triad(ax1_jcr_lca_upright)),
#    Eq({\bar{u}^{rbr_lca}_{jcr_lca_upright}}, -A({P_{rbr_lca}}).T*{R_{rbr_lca}} + A({P_{rbr_lca}}).T*pt1_jcr_lca_upright),
#    Eq({\bar{u}^{rbr_upright}_{jcr_lca_upright}}, -A({P_{rbr_upright}}).T*{R_{rbr_upright}} + A({P_{rbr_upright}}).T*pt1_jcr_lca_upright)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_lca}_{jcr_lca_upright}},
#    {\bar{M}^{rbr_upright}_{jcr_lca_upright}},
#    {\bar{u}^{rbr_lca}_{jcr_lca_upright}},
#    {\bar{u}^{rbr_upright}_{jcr_lca_upright}}]},
#  ('rbl_lca', 'ground', 'fas_rbl_lca_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbl_lca_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_lca_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6b15cf8>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbl_lca}_{gravity}}, Matrix([
#    [                0],
#    [                0],
#    [-9810.0*m_rbl_lca]]))],
#   'constants_symbols': [{{F}^{rbl_lca}_{gravity}}]},
#  ('rbl_lca', 'ground', 'fas_rbl_lca_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbl_lca_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_lca_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6b2f898>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbl_lca', 'ground', 'jcl_lca_chassis'): {'n': 0,
#   'nc': 5,
#   'nve': 3,
#   'class': uraeus.smbd.symbolic.components.joints.revolute,
#   'mirr': 'jcr_lca_chassis',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_lca_chassis',
#   'obj': <uraeus.smbd.symbolic.components.joints.revolute at 0x7fa6e6b2feb8>,
#   'arguments_symbols': [ax1_jcl_lca_chassis, pt1_jcl_lca_chassis],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_lca}_{jcl_lca_chassis}}, A({P_{rbl_lca}}).T*Triad(ax1_jcl_lca_chassis)),
#    Eq({\bar{M}^{ground}_{jcl_lca_chassis}}, A({P_{ground}}).T*Triad(ax1_jcl_lca_chassis)),
#    Eq({\bar{u}^{rbl_lca}_{jcl_lca_chassis}}, -A({P_{rbl_lca}}).T*{R_{rbl_lca}} + A({P_{rbl_lca}}).T*pt1_jcl_lca_chassis),
#    Eq({\bar{u}^{ground}_{jcl_lca_chassis}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt1_jcl_lca_chassis)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_lca}_{jcl_lca_chassis}},
#    {\bar{M}^{ground}_{jcl_lca_chassis}},
#    {\bar{u}^{rbl_lca}_{jcl_lca_chassis}},
#    {\bar{u}^{ground}_{jcl_lca_chassis}}]},
#  ('rbl_lca', 'rbl_upright', 'jcl_lca_upright'): {'n': 0,
#   'nc': 3,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.spherical,
#   'mirr': 'jcr_lca_upright',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_lca_upright',
#   'obj': <uraeus.smbd.symbolic.components.joints.spherical at 0x7fa6e6af1d68>,
#   'arguments_symbols': [ax1_jcl_lca_upright, pt1_jcl_lca_upright],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_lca}_{jcl_lca_upright}}, A({P_{rbl_lca}}).T*Triad(ax1_jcl_lca_upright)),
#    Eq({\bar{M}^{rbl_upright}_{jcl_lca_upright}}, A({P_{rbl_upright}}).T*Triad(ax1_jcl_lca_upright)),
#    Eq({\bar{u}^{rbl_lca}_{jcl_lca_upright}}, -A({P_{rbl_lca}}).T*{R_{rbl_lca}} + A({P_{rbl_lca}}).T*pt1_jcl_lca_upright),
#    Eq({\bar{u}^{rbl_upright}_{jcl_lca_upright}}, -A({P_{rbl_upright}}).T*{R_{rbl_upright}} + A({P_{rbl_upright}}).T*pt1_jcl_lca_upright)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_lca}_{jcl_lca_upright}},
#    {\bar{M}^{rbl_upright}_{jcl_lca_upright}},
#    {\bar{u}^{rbl_lca}_{jcl_lca_upright}},
#    {\bar{u}^{rbl_upright}_{jcl_lca_upright}}]},
#  ('rbr_upright', 'ground', 'fas_rbr_upright_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbr_upright_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_upright_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6a7ca58>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbr_upright}_{gravity}}, Matrix([
#    [                    0],
#    [                    0],
#    [-9810.0*m_rbr_upright]]))],
#   'constants_symbols': [{{F}^{rbr_upright}_{gravity}}]},
#  ('rbr_upright', 'ground', 'fas_rbr_upright_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbr_upright_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_upright_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6a97518>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbr_upright', 'ground', 'mcr_wheel_travel'): {'n': 0,
#   'nc': 1,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.absolute_locator,
#   'mirr': 'mcl_wheel_travel',
#   'align': 'r',
#   'virtual': False,
#   'name': 'mcr_wheel_travel',
#   'coordinate': 'z',
#   'obj': <uraeus.smbd.symbolic.components.joints.absolute_locator at 0x7fa6e6a97ef0>,
#   'arguments_symbols': [pt1_mcr_wheel_travel,
#    pt2_mcr_wheel_travel,
#    UF_mcr_wheel_travel],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{u}^{rbr_upright}_{mcr_wheel_travel}}, -A({P_{rbr_upright}}).T*{R_{rbr_upright}} + A({P_{rbr_upright}}).T*pt1_mcr_wheel_travel),
#    Eq({\bar{u}^{ground}_{mcr_wheel_travel}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt2_mcr_wheel_travel)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{u}^{rbr_upright}_{mcr_wheel_travel}},
#    {\bar{u}^{ground}_{mcr_wheel_travel}}]},
#  ('rbr_upright', 'rbr_hub', 'jcr_hub_bearing'): {'n': 0,
#   'nc': 5,
#   'nve': 3,
#   'class': uraeus.smbd.symbolic.components.joints.revolute,
#   'mirr': 'jcl_hub_bearing',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_hub_bearing',
#   'obj': <uraeus.smbd.symbolic.components.joints.revolute at 0x7fa6e6a976d8>,
#   'arguments_symbols': [ax1_jcr_hub_bearing, pt1_jcr_hub_bearing],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_upright}_{jcr_hub_bearing}}, A({P_{rbr_upright}}).T*Triad(ax1_jcr_hub_bearing)),
#    Eq({\bar{M}^{rbr_hub}_{jcr_hub_bearing}}, A({P_{rbr_hub}}).T*Triad(ax1_jcr_hub_bearing)),
#    Eq({\bar{u}^{rbr_upright}_{jcr_hub_bearing}}, -A({P_{rbr_upright}}).T*{R_{rbr_upright}} + A({P_{rbr_upright}}).T*pt1_jcr_hub_bearing),
#    Eq({\bar{u}^{rbr_hub}_{jcr_hub_bearing}}, -A({P_{rbr_hub}}).T*{R_{rbr_hub}} + A({P_{rbr_hub}}).T*pt1_jcr_hub_bearing)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_upright}_{jcr_hub_bearing}},
#    {\bar{M}^{rbr_hub}_{jcr_hub_bearing}},
#    {\bar{u}^{rbr_upright}_{jcr_hub_bearing}},
#    {\bar{u}^{rbr_hub}_{jcr_hub_bearing}}]},
#  ('rbr_upright', 'rbr_hub', 'mcr_wheel_lock'): {'n': 0,
#   'nc': 1,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.rotational_actuator,
#   'mirr': 'mcl_wheel_lock',
#   'align': 'r',
#   'virtual': False,
#   'name': 'mcr_wheel_lock',
#   'joint_name': 'jcr_hub_bearing',
#   'obj': <uraeus.smbd.symbolic.components.joints.rotational_actuator at 0x7fa6e92c93c8>,
#   'arguments_symbols': [ax1_jcr_hub_bearing, UF_mcr_wheel_lock],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_upright}_{jcr_hub_bearing}}, A({P_{rbr_upright}}).T*Triad(ax1_jcr_hub_bearing)),
#    Eq({\bar{M}^{rbr_hub}_{jcr_hub_bearing}}, A({P_{rbr_hub}}).T*Triad(ax1_jcr_hub_bearing))],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_upright}_{jcr_hub_bearing}},
#    {\bar{M}^{rbr_hub}_{jcr_hub_bearing}}]},
#  ('rbl_upright', 'ground', 'fas_rbl_upright_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbl_upright_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_upright_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6a3fc18>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbl_upright}_{gravity}}, Matrix([
#    [                    0],
#    [                    0],
#    [-9810.0*m_rbl_upright]]))],
#   'constants_symbols': [{{F}^{rbl_upright}_{gravity}}]},
#  ('rbl_upright', 'ground', 'fas_rbl_upright_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbl_upright_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_upright_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e933c0f0>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbl_upright', 'ground', 'mcl_wheel_travel'): {'n': 0,
#   'nc': 1,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.absolute_locator,
#   'mirr': 'mcr_wheel_travel',
#   'align': 'l',
#   'virtual': False,
#   'name': 'mcl_wheel_travel',
#   'coordinate': 'z',
#   'obj': <uraeus.smbd.symbolic.components.joints.absolute_locator at 0x7fa6e9328b70>,
#   'arguments_symbols': [pt1_mcl_wheel_travel,
#    pt2_mcl_wheel_travel,
#    UF_mcl_wheel_travel],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{u}^{rbl_upright}_{mcl_wheel_travel}}, -A({P_{rbl_upright}}).T*{R_{rbl_upright}} + A({P_{rbl_upright}}).T*pt1_mcl_wheel_travel),
#    Eq({\bar{u}^{ground}_{mcl_wheel_travel}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt2_mcl_wheel_travel)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{u}^{rbl_upright}_{mcl_wheel_travel}},
#    {\bar{u}^{ground}_{mcl_wheel_travel}}]},
#  ('rbl_upright', 'rbl_hub', 'jcl_hub_bearing'): {'n': 0,
#   'nc': 5,
#   'nve': 3,
#   'class': uraeus.smbd.symbolic.components.joints.revolute,
#   'mirr': 'jcr_hub_bearing',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_hub_bearing',
#   'obj': <uraeus.smbd.symbolic.components.joints.revolute at 0x7fa6e6bc95c0>,
#   'arguments_symbols': [ax1_jcl_hub_bearing, pt1_jcl_hub_bearing],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_upright}_{jcl_hub_bearing}}, A({P_{rbl_upright}}).T*Triad(ax1_jcl_hub_bearing)),
#    Eq({\bar{M}^{rbl_hub}_{jcl_hub_bearing}}, A({P_{rbl_hub}}).T*Triad(ax1_jcl_hub_bearing)),
#    Eq({\bar{u}^{rbl_upright}_{jcl_hub_bearing}}, -A({P_{rbl_upright}}).T*{R_{rbl_upright}} + A({P_{rbl_upright}}).T*pt1_jcl_hub_bearing),
#    Eq({\bar{u}^{rbl_hub}_{jcl_hub_bearing}}, -A({P_{rbl_hub}}).T*{R_{rbl_hub}} + A({P_{rbl_hub}}).T*pt1_jcl_hub_bearing)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_upright}_{jcl_hub_bearing}},
#    {\bar{M}^{rbl_hub}_{jcl_hub_bearing}},
#    {\bar{u}^{rbl_upright}_{jcl_hub_bearing}},
#    {\bar{u}^{rbl_hub}_{jcl_hub_bearing}}]},
#  ('rbl_upright', 'rbl_hub', 'mcl_wheel_lock'): {'n': 0,
#   'nc': 1,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.rotational_actuator,
#   'mirr': 'mcr_wheel_lock',
#   'align': 'l',
#   'virtual': False,
#   'name': 'mcl_wheel_lock',
#   'joint_name': 'jcl_hub_bearing',
#   'obj': <uraeus.smbd.symbolic.components.joints.rotational_actuator at 0x7fa6e6be3e80>,
#   'arguments_symbols': [ax1_jcl_hub_bearing, UF_mcl_wheel_lock],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_upright}_{jcl_hub_bearing}}, A({P_{rbl_upright}}).T*Triad(ax1_jcl_hub_bearing)),
#    Eq({\bar{M}^{rbl_hub}_{jcl_hub_bearing}}, A({P_{rbl_hub}}).T*Triad(ax1_jcl_hub_bearing))],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_upright}_{jcl_hub_bearing}},
#    {\bar{M}^{rbl_hub}_{jcl_hub_bearing}}]},
#  ('rbr_tie_rod', 'ground', 'fas_rbr_tie_rod_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbr_tie_rod_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_tie_rod_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6b98160>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbr_tie_rod}_{gravity}}, Matrix([
#    [                    0],
#    [                    0],
#    [-9810.0*m_rbr_tie_rod]]))],
#   'constants_symbols': [{{F}^{rbr_tie_rod}_{gravity}}]},
#  ('rbr_tie_rod', 'ground', 'fas_rbr_tie_rod_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbr_tie_rod_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_tie_rod_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6b88da0>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbr_tie_rod', 'rbr_upright', 'jcr_tie_upright'): {'n': 0,
#   'nc': 3,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.spherical,
#   'mirr': 'jcl_tie_upright',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_tie_upright',
#   'obj': <uraeus.smbd.symbolic.components.joints.spherical at 0x7fa6e6b98b38>,
#   'arguments_symbols': [ax1_jcr_tie_upright, pt1_jcr_tie_upright],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_tie_rod}_{jcr_tie_upright}}, A({P_{rbr_tie_rod}}).T*Triad(ax1_jcr_tie_upright)),
#    Eq({\bar{M}^{rbr_upright}_{jcr_tie_upright}}, A({P_{rbr_upright}}).T*Triad(ax1_jcr_tie_upright)),
#    Eq({\bar{u}^{rbr_tie_rod}_{jcr_tie_upright}}, -A({P_{rbr_tie_rod}}).T*{R_{rbr_tie_rod}} + A({P_{rbr_tie_rod}}).T*pt1_jcr_tie_upright),
#    Eq({\bar{u}^{rbr_upright}_{jcr_tie_upright}}, -A({P_{rbr_upright}}).T*{R_{rbr_upright}} + A({P_{rbr_upright}}).T*pt1_jcr_tie_upright)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_tie_rod}_{jcr_tie_upright}},
#    {\bar{M}^{rbr_upright}_{jcr_tie_upright}},
#    {\bar{u}^{rbr_tie_rod}_{jcr_tie_upright}},
#    {\bar{u}^{rbr_upright}_{jcr_tie_upright}}]},
#  ('rbr_tie_rod', 'rbs_steer_rack', 'jcr_tie_steering'): {'n': 0,
#   'nc': 4,
#   'nve': 2,
#   'class': uraeus.smbd.symbolic.components.joints.universal,
#   'mirr': 'jcl_tie_steering',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_tie_steering',
#   'obj': <uraeus.smbd.symbolic.components.joints.universal at 0x7fa6e6bae9e8>,
#   'arguments_symbols': [ax1_jcr_tie_steering,
#    ax2_jcr_tie_steering,
#    pt1_jcr_tie_steering],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_tie_rod}_{jcr_tie_steering}}, A({P_{rbr_tie_rod}}).T*Triad(ax1_jcr_tie_steering)),
#    Eq({\bar{M}^{rbs_steer_rack}_{jcr_tie_steering}}, A({P_{rbs_steer_rack}}).T*Triad(ax2_jcr_tie_steering, Triad(ax1_jcr_tie_steering)[:3, 1])),
#    Eq({\bar{u}^{rbr_tie_rod}_{jcr_tie_steering}}, -A({P_{rbr_tie_rod}}).T*{R_{rbr_tie_rod}} + A({P_{rbr_tie_rod}}).T*pt1_jcr_tie_steering),
#    Eq({\bar{u}^{rbs_steer_rack}_{jcr_tie_steering}}, -A({P_{rbs_steer_rack}}).T*{R_{rbs_steer_rack}} + A({P_{rbs_steer_rack}}).T*pt1_jcr_tie_steering)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_tie_rod}_{jcr_tie_steering}},
#    {\bar{M}^{rbs_steer_rack}_{jcr_tie_steering}},
#    {\bar{u}^{rbr_tie_rod}_{jcr_tie_steering}},
#    {\bar{u}^{rbs_steer_rack}_{jcr_tie_steering}}]},
#  ('rbl_tie_rod', 'ground', 'fas_rbl_tie_rod_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbl_tie_rod_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_tie_rod_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6b581d0>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbl_tie_rod}_{gravity}}, Matrix([
#    [                    0],
#    [                    0],
#    [-9810.0*m_rbl_tie_rod]]))],
#   'constants_symbols': [{{F}^{rbl_tie_rod}_{gravity}}]},
#  ('rbl_tie_rod', 'ground', 'fas_rbl_tie_rod_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbl_tie_rod_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_tie_rod_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6b496a0>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbl_tie_rod', 'rbl_upright', 'jcl_tie_upright'): {'n': 0,
#   'nc': 3,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.spherical,
#   'mirr': 'jcr_tie_upright',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_tie_upright',
#   'obj': <uraeus.smbd.symbolic.components.joints.spherical at 0x7fa6e6b49d30>,
#   'arguments_symbols': [ax1_jcl_tie_upright, pt1_jcl_tie_upright],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_tie_rod}_{jcl_tie_upright}}, A({P_{rbl_tie_rod}}).T*Triad(ax1_jcl_tie_upright)),
#    Eq({\bar{M}^{rbl_upright}_{jcl_tie_upright}}, A({P_{rbl_upright}}).T*Triad(ax1_jcl_tie_upright)),
#    Eq({\bar{u}^{rbl_tie_rod}_{jcl_tie_upright}}, -A({P_{rbl_tie_rod}}).T*{R_{rbl_tie_rod}} + A({P_{rbl_tie_rod}}).T*pt1_jcl_tie_upright),
#    Eq({\bar{u}^{rbl_upright}_{jcl_tie_upright}}, -A({P_{rbl_upright}}).T*{R_{rbl_upright}} + A({P_{rbl_upright}}).T*pt1_jcl_tie_upright)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_tie_rod}_{jcl_tie_upright}},
#    {\bar{M}^{rbl_upright}_{jcl_tie_upright}},
#    {\bar{u}^{rbl_tie_rod}_{jcl_tie_upright}},
#    {\bar{u}^{rbl_upright}_{jcl_tie_upright}}]},
#  ('rbl_tie_rod', 'rbs_steer_rack', 'jcl_tie_steering'): {'n': 0,
#   'nc': 4,
#   'nve': 2,
#   'class': uraeus.smbd.symbolic.components.joints.universal,
#   'mirr': 'jcr_tie_steering',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_tie_steering',
#   'obj': <uraeus.smbd.symbolic.components.joints.universal at 0x7fa6e6b67c88>,
#   'arguments_symbols': [ax1_jcl_tie_steering,
#    ax2_jcl_tie_steering,
#    pt1_jcl_tie_steering],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_tie_rod}_{jcl_tie_steering}}, A({P_{rbl_tie_rod}}).T*Triad(ax1_jcl_tie_steering)),
#    Eq({\bar{M}^{rbs_steer_rack}_{jcl_tie_steering}}, A({P_{rbs_steer_rack}}).T*Triad(ax2_jcl_tie_steering, Triad(ax1_jcl_tie_steering)[:3, 1])),
#    Eq({\bar{u}^{rbl_tie_rod}_{jcl_tie_steering}}, -A({P_{rbl_tie_rod}}).T*{R_{rbl_tie_rod}} + A({P_{rbl_tie_rod}}).T*pt1_jcl_tie_steering),
#    Eq({\bar{u}^{rbs_steer_rack}_{jcl_tie_steering}}, -A({P_{rbs_steer_rack}}).T*{R_{rbs_steer_rack}} + A({P_{rbs_steer_rack}}).T*pt1_jcl_tie_steering)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_tie_rod}_{jcl_tie_steering}},
#    {\bar{M}^{rbs_steer_rack}_{jcl_tie_steering}},
#    {\bar{u}^{rbl_tie_rod}_{jcl_tie_steering}},
#    {\bar{u}^{rbs_steer_rack}_{jcl_tie_steering}}]},
#  ('rbr_hub', 'ground', 'fas_rbr_hub_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbr_hub_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_hub_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6b06828>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbr_hub}_{gravity}}, Matrix([
#    [                0],
#    [                0],
#    [-9810.0*m_rbr_hub]]))],
#   'constants_symbols': [{{F}^{rbr_hub}_{gravity}}]},
#  ('rbr_hub', 'ground', 'fas_rbr_hub_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbr_hub_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_hub_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6afeb70>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbl_hub', 'ground', 'fas_rbl_hub_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbl_hub_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_hub_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6b155f8>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbl_hub}_{gravity}}, Matrix([
#    [                0],
#    [                0],
#    [-9810.0*m_rbl_hub]]))],
#   'constants_symbols': [{{F}^{rbl_hub}_{gravity}}]},
#  ('rbl_hub', 'ground', 'fas_rbl_hub_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbl_hub_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_hub_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6b15b70>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbr_upper_strut', 'ground', 'fas_rbr_upper_strut_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbr_upper_strut_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_upper_strut_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e69d7c88>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbr_upper_strut}_{gravity}}, Matrix([
#    [                        0],
#    [                        0],
#    [-9810.0*m_rbr_upper_strut]]))],
#   'constants_symbols': [{{F}^{rbr_upper_strut}_{gravity}}]},
#  ('rbr_upper_strut', 'ground', 'fas_rbr_upper_strut_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbr_upper_strut_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_upper_strut_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e69d7eb8>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbr_upper_strut', 'ground', 'jcr_strut_chassis'): {'n': 0,
#   'nc': 4,
#   'nve': 2,
#   'class': uraeus.smbd.symbolic.components.joints.universal,
#   'mirr': 'jcl_strut_chassis',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_strut_chassis',
#   'obj': <uraeus.smbd.symbolic.components.joints.universal at 0x7fa6e6b15d68>,
#   'arguments_symbols': [ax1_jcr_strut_chassis,
#    ax2_jcr_strut_chassis,
#    pt1_jcr_strut_chassis],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_upper_strut}_{jcr_strut_chassis}}, A({P_{rbr_upper_strut}}).T*Triad(ax1_jcr_strut_chassis)),
#    Eq({\bar{M}^{ground}_{jcr_strut_chassis}}, A({P_{ground}}).T*Triad(ax2_jcr_strut_chassis, Triad(ax1_jcr_strut_chassis)[:3, 1])),
#    Eq({\bar{u}^{rbr_upper_strut}_{jcr_strut_chassis}}, -A({P_{rbr_upper_strut}}).T*{R_{rbr_upper_strut}} + A({P_{rbr_upper_strut}}).T*pt1_jcr_strut_chassis),
#    Eq({\bar{u}^{ground}_{jcr_strut_chassis}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt1_jcr_strut_chassis)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_upper_strut}_{jcr_strut_chassis}},
#    {\bar{M}^{ground}_{jcr_strut_chassis}},
#    {\bar{u}^{rbr_upper_strut}_{jcr_strut_chassis}},
#    {\bar{u}^{ground}_{jcr_strut_chassis}}]},
#  ('rbr_upper_strut', 'rbr_lower_strut', 'jcr_strut'): {'n': 0,
#   'nc': 4,
#   'nve': 4,
#   'class': uraeus.smbd.symbolic.components.joints.cylinderical,
#   'mirr': 'jcl_strut',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_strut',
#   'obj': <uraeus.smbd.symbolic.components.joints.cylinderical at 0x7fa6e69f1c50>,
#   'arguments_symbols': [ax1_jcr_strut, pt1_jcr_strut],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_upper_strut}_{jcr_strut}}, A({P_{rbr_upper_strut}}).T*Triad(ax1_jcr_strut)),
#    Eq({\bar{M}^{rbr_lower_strut}_{jcr_strut}}, A({P_{rbr_lower_strut}}).T*Triad(ax1_jcr_strut)),
#    Eq({\bar{u}^{rbr_upper_strut}_{jcr_strut}}, -A({P_{rbr_upper_strut}}).T*{R_{rbr_upper_strut}} + A({P_{rbr_upper_strut}}).T*pt1_jcr_strut),
#    Eq({\bar{u}^{rbr_lower_strut}_{jcr_strut}}, -A({P_{rbr_lower_strut}}).T*{R_{rbr_lower_strut}} + A({P_{rbr_lower_strut}}).T*pt1_jcr_strut)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_upper_strut}_{jcr_strut}},
#    {\bar{M}^{rbr_lower_strut}_{jcr_strut}},
#    {\bar{u}^{rbr_upper_strut}_{jcr_strut}},
#    {\bar{u}^{rbr_lower_strut}_{jcr_strut}}]},
#  ('rbr_upper_strut', 'rbr_lower_strut', 'far_strut'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.internal_force,
#   'mirr': 'fal_strut',
#   'align': 'r',
#   'virtual': False,
#   'name': 'far_strut',
#   'obj': <uraeus.smbd.symbolic.components.forces.internal_force at 0x7fa6e6af1ba8>,
#   'arguments_symbols': [pt1_far_strut,
#    pt2_far_strut,
#    UF_far_strut_Fs,
#    UF_far_strut_Fd,
#    far_strut_FL],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{u}^{rbr_upper_strut}_{far_strut}}, -A({P_{rbr_upper_strut}}).T*{R_{rbr_upper_strut}} + A({P_{rbr_upper_strut}}).T*pt1_far_strut),
#    Eq({\bar{u}^{rbr_lower_strut}_{far_strut}}, -A({P_{rbr_lower_strut}}).T*{R_{rbr_lower_strut}} + A({P_{rbr_lower_strut}}).T*pt2_far_strut)],
#   'constants_numeric_expr': [Eq({{T}^{rbr_upper_strut}_{far_strut}}, zero_matrix(3,1)),
#    Eq({{T}^{rbr_lower_strut}_{far_strut}}, zero_matrix(3,1))],
#   'constants_symbols': [{\bar{u}^{rbr_upper_strut}_{far_strut}},
#    {\bar{u}^{rbr_lower_strut}_{far_strut}},
#    {{T}^{rbr_upper_strut}_{far_strut}},
#    {{T}^{rbr_lower_strut}_{far_strut}}]},
#  ('rbl_upper_strut', 'ground', 'fas_rbl_upper_strut_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbl_upper_strut_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_upper_strut_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6b7eeb8>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbl_upper_strut}_{gravity}}, Matrix([
#    [                        0],
#    [                        0],
#    [-9810.0*m_rbl_upper_strut]]))],
#   'constants_symbols': [{{F}^{rbl_upper_strut}_{gravity}}]},
#  ('rbl_upper_strut', 'ground', 'fas_rbl_upper_strut_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbl_upper_strut_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_upper_strut_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6a8be48>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbl_upper_strut', 'ground', 'jcl_strut_chassis'): {'n': 0,
#   'nc': 4,
#   'nve': 2,
#   'class': uraeus.smbd.symbolic.components.joints.universal,
#   'mirr': 'jcr_strut_chassis',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_strut_chassis',
#   'obj': <uraeus.smbd.symbolic.components.joints.universal at 0x7fa6e936d278>,
#   'arguments_symbols': [ax1_jcl_strut_chassis,
#    ax2_jcl_strut_chassis,
#    pt1_jcl_strut_chassis],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_upper_strut}_{jcl_strut_chassis}}, A({P_{rbl_upper_strut}}).T*Triad(ax1_jcl_strut_chassis)),
#    Eq({\bar{M}^{ground}_{jcl_strut_chassis}}, A({P_{ground}}).T*Triad(ax2_jcl_strut_chassis, Triad(ax1_jcl_strut_chassis)[:3, 1])),
#    Eq({\bar{u}^{rbl_upper_strut}_{jcl_strut_chassis}}, -A({P_{rbl_upper_strut}}).T*{R_{rbl_upper_strut}} + A({P_{rbl_upper_strut}}).T*pt1_jcl_strut_chassis),
#    Eq({\bar{u}^{ground}_{jcl_strut_chassis}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt1_jcl_strut_chassis)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_upper_strut}_{jcl_strut_chassis}},
#    {\bar{M}^{ground}_{jcl_strut_chassis}},
#    {\bar{u}^{rbl_upper_strut}_{jcl_strut_chassis}},
#    {\bar{u}^{ground}_{jcl_strut_chassis}}]},
#  ('rbl_upper_strut', 'rbl_lower_strut', 'jcl_strut'): {'n': 0,
#   'nc': 4,
#   'nve': 4,
#   'class': uraeus.smbd.symbolic.components.joints.cylinderical,
#   'mirr': 'jcr_strut',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_strut',
#   'obj': <uraeus.smbd.symbolic.components.joints.cylinderical at 0x7fa6e936d828>,
#   'arguments_symbols': [ax1_jcl_strut, pt1_jcl_strut],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_upper_strut}_{jcl_strut}}, A({P_{rbl_upper_strut}}).T*Triad(ax1_jcl_strut)),
#    Eq({\bar{M}^{rbl_lower_strut}_{jcl_strut}}, A({P_{rbl_lower_strut}}).T*Triad(ax1_jcl_strut)),
#    Eq({\bar{u}^{rbl_upper_strut}_{jcl_strut}}, -A({P_{rbl_upper_strut}}).T*{R_{rbl_upper_strut}} + A({P_{rbl_upper_strut}}).T*pt1_jcl_strut),
#    Eq({\bar{u}^{rbl_lower_strut}_{jcl_strut}}, -A({P_{rbl_lower_strut}}).T*{R_{rbl_lower_strut}} + A({P_{rbl_lower_strut}}).T*pt1_jcl_strut)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_upper_strut}_{jcl_strut}},
#    {\bar{M}^{rbl_lower_strut}_{jcl_strut}},
#    {\bar{u}^{rbl_upper_strut}_{jcl_strut}},
#    {\bar{u}^{rbl_lower_strut}_{jcl_strut}}]},
#  ('rbl_upper_strut', 'rbl_lower_strut', 'fal_strut'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.internal_force,
#   'mirr': 'far_strut',
#   'align': 'l',
#   'virtual': False,
#   'name': 'fal_strut',
#   'obj': <uraeus.smbd.symbolic.components.forces.internal_force at 0x7fa6e933ce10>,
#   'arguments_symbols': [pt1_fal_strut,
#    pt2_fal_strut,
#    UF_fal_strut_Fs,
#    UF_fal_strut_Fd,
#    fal_strut_FL],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{u}^{rbl_upper_strut}_{fal_strut}}, -A({P_{rbl_upper_strut}}).T*{R_{rbl_upper_strut}} + A({P_{rbl_upper_strut}}).T*pt1_fal_strut),
#    Eq({\bar{u}^{rbl_lower_strut}_{fal_strut}}, -A({P_{rbl_lower_strut}}).T*{R_{rbl_lower_strut}} + A({P_{rbl_lower_strut}}).T*pt2_fal_strut)],
#   'constants_numeric_expr': [Eq({{T}^{rbl_upper_strut}_{fal_strut}}, zero_matrix(3,1)),
#    Eq({{T}^{rbl_lower_strut}_{fal_strut}}, zero_matrix(3,1))],
#   'constants_symbols': [{\bar{u}^{rbl_upper_strut}_{fal_strut}},
#    {\bar{u}^{rbl_lower_strut}_{fal_strut}},
#    {{T}^{rbl_upper_strut}_{fal_strut}},
#    {{T}^{rbl_lower_strut}_{fal_strut}}]},
#  ('rbr_lower_strut', 'ground', 'fas_rbr_lower_strut_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbr_lower_strut_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_lower_strut_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e9328470>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbr_lower_strut}_{gravity}}, Matrix([
#    [                        0],
#    [                        0],
#    [-9810.0*m_rbr_lower_strut]]))],
#   'constants_symbols': [{{F}^{rbr_lower_strut}_{gravity}}]},
#  ('rbr_lower_strut', 'ground', 'fas_rbr_lower_strut_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbr_lower_strut_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbr_lower_strut_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e69fc358>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbr_lower_strut', 'rbr_uca', 'jcr_strut_uca'): {'n': 0,
#   'nc': 4,
#   'nve': 2,
#   'class': uraeus.smbd.symbolic.components.joints.universal,
#   'mirr': 'jcl_strut_uca',
#   'align': 'r',
#   'virtual': False,
#   'name': 'jcr_strut_uca',
#   'obj': <uraeus.smbd.symbolic.components.joints.universal at 0x7fa6e69025c0>,
#   'arguments_symbols': [ax1_jcr_strut_uca,
#    ax2_jcr_strut_uca,
#    pt1_jcr_strut_uca],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbr_lower_strut}_{jcr_strut_uca}}, A({P_{rbr_lower_strut}}).T*Triad(ax1_jcr_strut_uca)),
#    Eq({\bar{M}^{rbr_uca}_{jcr_strut_uca}}, A({P_{rbr_uca}}).T*Triad(ax2_jcr_strut_uca, Triad(ax1_jcr_strut_uca)[:3, 1])),
#    Eq({\bar{u}^{rbr_lower_strut}_{jcr_strut_uca}}, -A({P_{rbr_lower_strut}}).T*{R_{rbr_lower_strut}} + A({P_{rbr_lower_strut}}).T*pt1_jcr_strut_uca),
#    Eq({\bar{u}^{rbr_uca}_{jcr_strut_uca}}, -A({P_{rbr_uca}}).T*{R_{rbr_uca}} + A({P_{rbr_uca}}).T*pt1_jcr_strut_uca)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbr_lower_strut}_{jcr_strut_uca}},
#    {\bar{M}^{rbr_uca}_{jcr_strut_uca}},
#    {\bar{u}^{rbr_lower_strut}_{jcr_strut_uca}},
#    {\bar{u}^{rbr_uca}_{jcr_strut_uca}}]},
#  ('rbl_lower_strut', 'ground', 'fas_rbl_lower_strut_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbl_lower_strut_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_lower_strut_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e69fc588>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbl_lower_strut}_{gravity}}, Matrix([
#    [                        0],
#    [                        0],
#    [-9810.0*m_rbl_lower_strut]]))],
#   'constants_symbols': [{{F}^{rbl_lower_strut}_{gravity}}]},
#  ('rbl_lower_strut', 'ground', 'fas_rbl_lower_strut_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbl_lower_strut_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbl_lower_strut_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6bf3588>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbl_lower_strut', 'rbl_uca', 'jcl_strut_uca'): {'n': 0,
#   'nc': 4,
#   'nve': 2,
#   'class': uraeus.smbd.symbolic.components.joints.universal,
#   'mirr': 'jcr_strut_uca',
#   'align': 'l',
#   'virtual': False,
#   'name': 'jcl_strut_uca',
#   'obj': <uraeus.smbd.symbolic.components.joints.universal at 0x7fa6e6b88ef0>,
#   'arguments_symbols': [ax1_jcl_strut_uca,
#    ax2_jcl_strut_uca,
#    pt1_jcl_strut_uca],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbl_lower_strut}_{jcl_strut_uca}}, A({P_{rbl_lower_strut}}).T*Triad(ax1_jcl_strut_uca)),
#    Eq({\bar{M}^{rbl_uca}_{jcl_strut_uca}}, A({P_{rbl_uca}}).T*Triad(ax2_jcl_strut_uca, Triad(ax1_jcl_strut_uca)[:3, 1])),
#    Eq({\bar{u}^{rbl_lower_strut}_{jcl_strut_uca}}, -A({P_{rbl_lower_strut}}).T*{R_{rbl_lower_strut}} + A({P_{rbl_lower_strut}}).T*pt1_jcl_strut_uca),
#    Eq({\bar{u}^{rbl_uca}_{jcl_strut_uca}}, -A({P_{rbl_uca}}).T*{R_{rbl_uca}} + A({P_{rbl_uca}}).T*pt1_jcl_strut_uca)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbl_lower_strut}_{jcl_strut_uca}},
#    {\bar{M}^{rbl_uca}_{jcl_strut_uca}},
#    {\bar{u}^{rbl_lower_strut}_{jcl_strut_uca}},
#    {\bar{u}^{rbl_uca}_{jcl_strut_uca}}]},
#  ('rbs_steer_rack', 'ground', 'fas_rbs_steer_rack_gravity'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.gravity_force,
#   'mirr': 'fas_rbs_steer_rack_gravity',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbs_steer_rack_gravity',
#   'obj': <uraeus.smbd.symbolic.components.forces.gravity_force at 0x7fa6e6a1f6a0>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [Eq({{F}^{rbs_steer_rack}_{gravity}}, Matrix([
#    [                       0],
#    [                       0],
#    [-9810.0*m_rbs_steer_rack]]))],
#   'constants_symbols': [{{F}^{rbs_steer_rack}_{gravity}}]},
#  ('rbs_steer_rack', 'ground', 'fas_rbs_steer_rack_centrifuge'): {'n': 0,
#   'nc': 0,
#   'nve': 0,
#   'class': uraeus.smbd.symbolic.components.forces.centrifugal_force,
#   'mirr': 'fas_rbs_steer_rack_centrifuge',
#   'align': 's',
#   'virtual': False,
#   'name': 'fas_rbs_steer_rack_centrifuge',
#   'obj': <uraeus.smbd.symbolic.components.forces.centrifugal_force at 0x7fa6e6bae3c8>,
#   'arguments_symbols': [],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [],
#   'constants_numeric_expr': [],
#   'constants_symbols': []},
#  ('rbs_steer_rack', 'ground', 'jcs_rack'): {'n': 0,
#   'nc': 5,
#   'nve': 5,
#   'class': uraeus.smbd.symbolic.components.joints.translational,
#   'mirr': 'jcs_rack',
#   'align': 's',
#   'virtual': False,
#   'name': 'jcs_rack',
#   'obj': <uraeus.smbd.symbolic.components.joints.translational at 0x7fa6e6a1f400>,
#   'arguments_symbols': [ax1_jcs_rack, pt1_jcs_rack],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbs_steer_rack}_{jcs_rack}}, A({P_{rbs_steer_rack}}).T*Triad(ax1_jcs_rack)),
#    Eq({\bar{M}^{ground}_{jcs_rack}}, A({P_{ground}}).T*Triad(ax1_jcs_rack)),
#    Eq({\bar{u}^{rbs_steer_rack}_{jcs_rack}}, -A({P_{rbs_steer_rack}}).T*{R_{rbs_steer_rack}} + A({P_{rbs_steer_rack}}).T*pt1_jcs_rack),
#    Eq({\bar{u}^{ground}_{jcs_rack}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt1_jcs_rack)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbs_steer_rack}_{jcs_rack}},
#    {\bar{M}^{ground}_{jcs_rack}},
#    {\bar{u}^{rbs_steer_rack}_{jcs_rack}},
#    {\bar{u}^{ground}_{jcs_rack}}]},
#  ('rbs_steer_rack', 'ground', 'mcs_rack_travel'): {'n': 0,
#   'nc': 1,
#   'nve': 1,
#   'class': uraeus.smbd.symbolic.components.joints.translational_actuator,
#   'mirr': 'mcs_rack_travel',
#   'align': 's',
#   'virtual': False,
#   'name': 'mcs_rack_travel',
#   'joint_name': 'jcs_rack',
#   'obj': <uraeus.smbd.symbolic.components.joints.translational_actuator at 0x7fa6e6b67da0>,
#   'arguments_symbols': [ax1_jcs_rack, pt1_jcs_rack, UF_mcs_rack_travel],
#   'runtime_symbols': [],
#   'constants_symbolic_expr': [Eq({\bar{M}^{rbs_steer_rack}_{jcs_rack}}, A({P_{rbs_steer_rack}}).T*Triad(ax1_jcs_rack)),
#    Eq({\bar{M}^{ground}_{jcs_rack}}, A({P_{ground}}).T*Triad(ax1_jcs_rack)),
#    Eq({\bar{u}^{rbs_steer_rack}_{jcs_rack}}, -A({P_{rbs_steer_rack}}).T*{R_{rbs_steer_rack}} + A({P_{rbs_steer_rack}}).T*pt1_jcs_rack),
#    Eq({\bar{u}^{ground}_{jcs_rack}}, -A({P_{ground}}).T*{R_{ground}} + A({P_{ground}}).T*pt1_jcs_rack)],
#   'constants_numeric_expr': [],
#   'constants_symbols': [{\bar{M}^{rbs_steer_rack}_{jcs_rack}},
#    {\bar{M}^{ground}_{jcs_rack}},
#    {\bar{u}^{rbs_steer_rack}_{jcs_rack}},
#    {\bar{u}^{ground}_{jcs_rack}}]}}

# %% [markdown]
# ---------------------------------------------------------------
# ---------------------------------------------------------------

# %% [markdown]
# ## **SYSTEM CONFIGURATION**
# ---------------------------

# %% [markdown]
# In this step we define a symbolic configuration of our symbolic topology. As you may have noticed in the symbolic topology building step, we only cared about the **_topology_**, thats is the system bodies and their connectivity, and we did not care explicitly with how these components are configured in space.</br>
#
# In order to create a valid numerical simulation session, we have to provide the system with its numerical configuration needed, for example, the joints' locations and orientations. The symbolic topology in its raw form will require you to manually enter all these numerical arguments, which can be cumbersome even for smaller systems. This can be checked by checking the configuration inputs of the symbolic configuration as ```sym_config.config.input_nodes```
#
# Here we start by stating the symbolic inputs we wish to use instead of the default inputs set, and then we define the relation between these newly defined arguments and the original ones.
#
# **_The details of this process will be provided in the documentation._**

# %%
# Symbolic configuration name.
config_name = '%s_cfg'%project_name

# Symbolic configuration instance.
sym_config = configuration(config_name, sym_model)

# %% [markdown]
# ### CONFIGURATION INPUTS

# %%
# Adding the desired set of UserInputs
# ====================================

sym_config.add_point.UserInput('ucaf', mirror=True)
sym_config.add_point.UserInput('ucar', mirror=True)
sym_config.add_point.UserInput('ucao', mirror=True)

sym_config.add_point.UserInput('lcaf', mirror=True)
sym_config.add_point.UserInput('lcar', mirror=True)
sym_config.add_point.UserInput('lcao', mirror=True)

sym_config.add_point.UserInput('tro', mirror=True)
sym_config.add_point.UserInput('tri', mirror=True)

sym_config.add_point.UserInput('strut_chassis', mirror=True)
sym_config.add_point.UserInput('strut_arm', mirror=True)
sym_config.add_point.UserInput('strut_mid', mirror=True)

sym_config.add_point.UserInput('wc', mirror=True)
sym_config.add_point.UserInput('wc1', mirror=True)
sym_config.add_point.UserInput('wc2', mirror=True)

sym_config.add_vector.UserInput('x')
sym_config.add_vector.UserInput('y')
sym_config.add_vector.UserInput('z')

# %% [markdown]
# ### CONFIGURATION RELATIONS

# %%
# Defining Relations between original topology inputs
# and our desired UserInputs.
# ===================================================


sym_config.add_point.Centered('strut_mid', ('hpr_strut_chassis', 'hpr_strut_arm'), mirror=True)

# Spherical Joints:
# =================
sym_config.add_relation.Equal_to('pt1_jcr_uca_upright', ('hpr_ucao',), mirror=True)
sym_config.add_relation.Equal_to('ax1_jcr_uca_upright', ('vcs_z',), mirror=True)

sym_config.add_relation.Equal_to('pt1_jcr_lca_upright', ('hpr_lcao',), mirror=True)
sym_config.add_relation.Equal_to('ax1_jcr_lca_upright', ('vcs_z',), mirror=True)

sym_config.add_relation.Equal_to('pt1_jcr_tie_upright', ('hpr_tro',), mirror=True)
sym_config.add_relation.Equal_to('ax1_jcr_tie_upright', ('vcs_z',), mirror=True)

# Upper Control Arm Revolute Joint:
# =================================
sym_config.add_relation.Centered('pt1_jcr_uca_chassis', ('hpr_ucaf','hpr_ucar'), mirror=True)
sym_config.add_relation.Oriented('ax1_jcr_uca_chassis', ('hpr_ucaf','hpr_ucar'), mirror=True)

# Lower Control Arm Revolute Joint:
# =================================
sym_config.add_relation.Centered('pt1_jcr_lca_chassis', ('hpr_lcaf','hpr_lcar'), mirror=True)
sym_config.add_relation.Oriented('ax1_jcr_lca_chassis', ('hpr_lcaf','hpr_lcar'), mirror=True)

# Wheel Hub Revolute Joint:
# =========================
sym_config.add_relation.Equal_to('pt1_jcr_hub_bearing', ('hpr_wc',), mirror=True)
sym_config.add_relation.Equal_to('ax1_jcr_hub_bearing', ('vcs_y',), mirror=True)

# Strut-Chassis Universal Joint:
# ==============================
sym_config.add_relation.Equal_to('pt1_jcr_strut_chassis', ('hpr_strut_chassis',), mirror=True)
sym_config.add_relation.Oriented('ax1_jcr_strut_chassis', ('hpr_strut_chassis','hpr_strut_arm'), mirror=True)
sym_config.add_relation.Oriented('ax2_jcr_strut_chassis', ('hpr_strut_arm','hpr_strut_chassis'), mirror=True)

# Strut-Control-Arm Universal Joint:
# ==================================
sym_config.add_relation.Equal_to('pt1_jcr_strut_uca', ('hpr_strut_arm',), mirror=True)
sym_config.add_relation.Oriented('ax1_jcr_strut_uca', ('hpr_strut_chassis','hpr_strut_arm'), mirror=True)
sym_config.add_relation.Oriented('ax2_jcr_strut_uca', ('hpr_strut_arm','hpr_strut_chassis'), mirror=True)

# Tie-Steer Universal Joint:
# ==========================
sym_config.add_relation.Equal_to('pt1_jcr_tie_steering', ('hpr_tri',), mirror=True)
sym_config.add_relation.Oriented('ax1_jcr_tie_steering', ('hpr_tri','hpr_tro'), mirror=True)
sym_config.add_relation.Oriented('ax2_jcr_tie_steering', ('hpr_tro','hpr_tri'), mirror=True)

# Strut Cylinderical Joint:
# =========================
sym_config.add_relation.Equal_to('pt1_jcr_strut', ('hpr_strut_mid',), mirror=True)
sym_config.add_relation.Oriented('ax1_jcr_strut', ('hpr_strut_arm','hpr_strut_chassis'), mirror=True)

# Rack Translational Joint:
# =========================
sym_config.add_relation.Centered('pt1_jcs_rack', ('hpr_tri', 'hpl_tri'))
sym_config.add_relation.Oriented('ax1_jcs_rack', ('hpr_tri', 'hpl_tri'))

# %% [markdown]
# ### GEOMETRIES

# %% [markdown]
# Here we start defining basic geometric shapes that can represents the shapes of the bodies in our system. This serves two points:
# - Visualization and Animation in blender.
# - Evaluating the bodies inertia properties from these basic geometries instead of explicit definition.

# %%
# ===================
# Creating Geometries
# ===================
sym_config.add_scalar.UserInput('links_ro')
sym_config.add_scalar.UserInput('strut_outer')
sym_config.add_scalar.UserInput('strut_inner')
sym_config.add_scalar.UserInput('thickness')
sym_config.add_scalar.UserInput('hub_radius')


# Upper Control Arm Geometry.
sym_config.add_geometry.Triangular_Prism('uca', ('hpr_ucaf','hpr_ucar','hpr_ucao','s_thickness'), mirror=True)
sym_config.assign_geometry_to_body('rbr_uca', 'gmr_uca', mirror=True)

# Lower Control Arm Geometry.
sym_config.add_geometry.Triangular_Prism('lca', ('hpr_lcaf','hpr_lcar','hpr_lcao','s_thickness'), mirror=True)
sym_config.assign_geometry_to_body('rbr_lca', 'gmr_lca', mirror=True)

# Upright (Wheel-Carrier) Geometry.
sym_config.add_geometry.Triangular_Prism('upright', ('hpr_ucao','hpr_wc','hpr_lcao','s_thickness'), mirror=True)
sym_config.assign_geometry_to_body('rbr_upright', 'gmr_upright', mirror=True)

# Upper Strut Cylinder Geometry.
sym_config.add_geometry.Cylinder_Geometry('upper_strut', ('hpr_strut_chassis','hpr_strut_mid','s_strut_outer'), mirror=True)
sym_config.assign_geometry_to_body('rbr_upper_strut', 'gmr_upper_strut', mirror=True)

# Lower Strut Cylinder Geometry.
sym_config.add_geometry.Cylinder_Geometry('lower_strut', ('hpr_strut_mid','hpr_strut_arm','s_strut_inner'), mirror=True)
sym_config.assign_geometry_to_body('rbr_lower_strut', 'gmr_lower_strut', mirror=True)

# Tie-Rod Cylinder Geometry.
sym_config.add_geometry.Cylinder_Geometry('tie_rod', ('hpr_tri','hpr_tro','s_links_ro'), mirror=True)
sym_config.assign_geometry_to_body('rbr_tie_rod', 'gmr_tie_rod', mirror=True)

# Tire/Hub Geometry.
sym_config.add_geometry.Cylinder_Geometry('hub', ('hpr_wc1','hpr_wc2','s_hub_radius'), mirror=True)
sym_config.assign_geometry_to_body('rbr_hub', 'gmr_hub', mirror=True)

# Steering Rack Geometry
sym_config.add_geometry.Cylinder_Geometry('steer_rack', ('hpr_tri', 'hpl_tri','s_links_ro'))
sym_config.assign_geometry_to_body('rbs_steer_rack', 'gms_steer_rack')

# %% [markdown]
# Exporting configuration into a JSON file

# %%
sym_config.export_JSON_file('')

# %% [markdown]
# ---------------------------------------------------------------
# ---------------------------------------------------------------
